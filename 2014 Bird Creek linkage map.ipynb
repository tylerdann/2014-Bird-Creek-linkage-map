# %% [markdown]
# # Background on rounds of sequencing

# %% [markdown]
# Two families were chosen for sequencing, offspring from female 101 and female 110.  Both gynogenetic diploids and haploids were included in library prep and sequencing with the following sample sizes:
# 101: haploid=49, gyno diploid=23
# 107: haploid=118
# Together with dams 101 and 102 we prepared two libraries of 96 individuals each.
#
# Libraries were mistakenly swapped on the instrument during the first round of sequencing, resulting in incorrect titrations for the second round of sequencing and inbalanced coverage among individuals.  A third round of sequencing was conducted but didn't result in adequate coverage for the smaller group of 101 haploid individuals to be useful in estimating recombination frequencies.  Finally, we used the instrument training run on ADF&G's NextSeq 500 to try and resurrect 101 haploid individuals and incorporate variation from dam 101 on the linkage map.

# %% [markdown]
# ## Processing .fastq from final round of sequencing

# %%
! process_radtags -P -p '/media/tyler/My Book/Stacks/Pink/Haploids2014/Training Ogo Run/fastq' -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/OgoTrainingStacks' -b '/media/tyler/My Book/Stacks/Pink/Haploids2014/Training Ogo Run/Bird2014TrainingRunBarcodes.txt' -E phred33 -e sbfI -i gzfastq -c -r -q --filter_illumina
# Out:
# Processing paired-end data.
# Using Phred+33 encoding for quality scores.
# Discarding reads marked as 'failed' by Illumina's chastity/purity filters.
# Found 1 paired input file(s).
# Searching for single-end, inlined barcodes.
# Loaded 32 barcodes (6bp).
# Will attempt to recover barcodes with at most 1 mismatches.
# Processing file 1 of 1 [Undetermined_S0_R1_001.fastq.gz]
#   Reading data from:
#   /media/tyler/My Book/Stacks/Pink/Haploids2014/Training Ogo Run/fastq/Undetermined_S0_R1_001.fastq.gz and
#   /media/tyler/My Book/Stacks/Pink/Haploids2014/Training Ogo Run/fastq/Undetermined_S0_R2_001.fastq.gz
# ...

# %% [markdown]
# ### Same process radtags but trimming to 94 bases to align with previously collected data

# %%
! process_radtags -P -p '/media/tyler/My Book/Stacks/Pink/Haploids2014/Training Ogo Run/fastq' -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/OgoTrainingStacks/t94' -b '/media/tyler/My Book/Stacks/Pink/Haploids2014/Training Ogo Run/Bird2014TrainingRunBarcodes.txt' -E phred33 -e sbfI -i gzfastq -t 94 -c -r -q --filter_illumina
# Out:
# Processing paired-end data.
# Using Phred+33 encoding for quality scores.
# Reads will be truncated to 94bp
# Discarding reads marked as 'failed' by Illumina's chastity/purity filters.
# Found 1 paired input file(s).
# Searching for single-end, inlined barcodes.
# Loaded 32 barcodes (6bp).
# Will attempt to recover barcodes with at most 1 mismatches.
# Processing file 1 of 1 [Undetermined_S0_R1_001.fastq.gz]
#   Reading data from:
#   /media/tyler/My Book/Stacks/Pink/Haploids2014/Training Ogo Run/fastq/Undetermined_S0_R1_001.fastq.gz and
#   /media/tyler/My Book/Stacks/Pink/Haploids2014/Training Ogo Run/fastq/Undetermined_S0_R2_001.fastq.gz
# ...

# %% [markdown]
# ## Description of the four rounds of sequencing for 2014 Bird Creek haploids

# %% [markdown]
# Protocol when the two 2014 Bird Creek libraries (PHap1 and PHap2) were created was to conduct two rounds of sequencing to equalize coverage among individuals, titrating before the second round according to retained reads from the first round.
#
# Unfortunately the two libraries were swapped when sequenced at the Core lab for the first round, resulting in incorrect titrations and no equalizing of coverage.  A third round was done on a subset of individuals to rescue them from too few reads.  The final round (unpacked above) was acquired during ADF&G's training run.
#
#
# |         |                        | Barcode key used in: |               |                     |                 |
# |---------|------------------------|:--------------------:|:-------------:|:-------------------:|:---------------:|
# | Library | Originally planned key | Round 1              | ReRun         | ReReRun             | Round 4         |
# | PHap1   | PHap1Barcodes          | PHap2Barcodes        | PHap1Barcodes | PHapReReSeqBarcodes | PHap1 (partial) |
# | PHap2   | PHap2Barcodes          | PHap1Barcodes        | PHap2Barcodes |                     |                 |

# %%
! process_radtags -p '/media/tyler/My Book/Stacks/Pink/Haploids2014/PHapReReSeq' -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/PHapReReSeqStacks' -b '/media/tyler/My Book/Stacks/Pink/Haploids2014/PHapReReSeqBarcodes.txt' -E phred33 -e sbfI -i gzfastq -t 94 -c -r -q --filter_illumina
# Out:
# Processing single-end data.
# Using Phred+33 encoding for quality scores.
# Reads will be truncated to 94bp
# Discarding reads marked as 'failed' by Illumina's chastity/purity filters.
# Found 1 input file(s).
# Searching for single-end, inlined barcodes.
# Loaded 59 barcodes (6bp).
# Will attempt to recover barcodes with at most 1 mismatches.
# Processing file 1 of 1 [Phaps2014_NoIndex_S97_L007_R1_001.fastq.gz]
# ...

# %%
## Also rerunning process radtags on initial and resequence rounds for both libraries so that everything starts fresh from stacks 1.46
! process_radtags -p '/media/tyler/My Book/Stacks/Pink/Haploids2014/PHap1' -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/PHap2Stacks' -b '/media/tyler/My Book/Stacks/Pink/Haploids2014/PHap2Barcodes.txt' -e sbfI -c -r -q -E phred33 --filter_illumina -i gzfastq -t 94
! process_radtags -p '/media/tyler/My Book/Stacks/Pink/Haploids2014/PHap2' -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/PHap1Stacks' -b '/media/tyler/My Book/Stacks/Pink/Haploids2014/PHap1Barcodes.txt' -e sbfI -c -r -q -E phred33 --filter_illumina -i gzfastq -t 94
! process_radtags -p '/media/tyler/My Book/Stacks/Pink/Haploids2014/PHap1Rerun' -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/PHap1RerunStacks' -b '/media/tyler/My Book/Stacks/Pink/Haploids2014/PHap1Barcodes.txt' -e sbfI -c -r -q -E phred33 --filter_illumina -i gzfastq -t 94
! process_radtags -p '/media/tyler/My Book/Stacks/Pink/Haploids2014/PHap2Rerun' -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/PHap2RerunStacks' -b '/media/tyler/My Book/Stacks/Pink/Haploids2014/PHap2Barcodes.txt' -e sbfI -c -r -q -E phred33 --filter_illumina -i gzfastq -t 94
# Out:
# Processing single-end data.
# Using Phred+33 encoding for quality scores.
# Reads will be truncated to 94bp
# Discarding reads marked as 'failed' by Illumina's chastity/purity filters.
# Found 15 input file(s).
# Searching for single-end, inlined barcodes.
# Loaded 96 barcodes (6bp).
# Will attempt to recover barcodes with at most 1 mismatches.
# Processing file 1 of 15 [PHap1_lane5_NoIndex_L005_R1_007.fastq.gz]
#   Processing RAD-Tags...1M...2M...3M...4M...5M...6M...7M...8M...9M...10M...11M...12M...13M...14M...15M...16M...
#   16000000 total reads; -1841729 failed Illumina reads; -4861645 ambiguous barcodes; -3275420 ambiguous RAD-Tags; +3998931 recovered; -413159 low quality reads; 5608047 retained reads.
# Processing file 2 of 15 [PHap1_lane5_NoIndex_L005_R1_001.fastq.gz]
#   Processing RAD-Tags...1M...2M...3M...4M...5M...6M...7M...8M...9M...10M...11M...12M...13M...14M...15M...16M...
# ...

# %%
## Paired end reads have two .fq along with .rem for each sample corresponding to read 1 and 2 (and reads thrown out .rem).
## Running process_radtags with single end to only look at read 1 for comparison purposes and maybe make concatenation easier.
! process_radtags -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Training Ogo Run/fastq/Undetermined_S0_R1_001.fastq.gz' -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/OgoTrainingStacks/SingleEndt94' -b '/media/tyler/My Book/Stacks/Pink/Haploids2014/Training Ogo Run/Bird2014TrainingRunBarcodes.txt' -E phred33 -e sbfI -i gzfastq -c -r -q --filter_illumina
# Out:
# Processing single-end data.
# Using Phred+33 encoding for quality scores.
# Discarding reads marked as 'failed' by Illumina's chastity/purity filters.
# Found 1 input file(s).
# Searching for single-end, inlined barcodes.
# Loaded 32 barcodes (6bp).
# Will attempt to recover barcodes with at most 1 mismatches.
# Processing file 1 of 1 [Undetermined_S0_R1_001.fastq.gz]
# ...

# %% [markdown]
# ## Concatenate multiple rounds of sequence - single-end and trimmed to 94 bp data

# %%
! cat '/media/tyler/My Book/Stacks/Pink/Haploids2014/PHap1Stacks/PBIRD14
> '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0126.fq.gz'

# %% [markdown]
# ## ustacks with single-end trimmed data - using standard parameter values for m (min depth coverage to create a stack) and M (maximum distance allowed between stacks) and enabling the deleveraging algorithm to remove highly repetitive stacks.

# %%
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X_0101.fq.gz' -i  5000 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101G_0013.fq.gz' -i  5001 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101G_0014.fq.gz' -i  5002 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101G_0015.fq.gz' -i  5003 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101G_0016.fq.gz' -i  5004 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101G_0017.fq.gz' -i  5005 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101G_0018.fq.gz' -i  5006 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101G_0019.fq.gz' -i  5007 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101G_0020.fq.gz' -i  5008 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101G_0021.fq.gz' -i  5009 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101G_0022.fq.gz' -i  5010 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101G_0023.fq.gz' -i  5011 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101H_0002.fq.gz' -i  5012 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101H_0003.fq.gz' -i  5013 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101H_0005.fq.gz' -i  5014 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101H_0007.fq.gz' -i  5015 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101H_0009.fq.gz' -i  5016 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101H_0010.fq.gz' -i  5017 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101H_0011.fq.gz' -i  5018 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101H_0012.fq.gz' -i  5019 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101H_0013.fq.gz' -i  5020 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101H_0014.fq.gz' -i  5021 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101H_0015.fq.gz' -i  5022 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101H_0016.fq.gz' -i  5023 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101H_0017.fq.gz' -i  5024 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101H_0018.fq.gz' -i  5025 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101H_0019.fq.gz' -i  5026 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101H_0020.fq.gz' -i  5027 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101H_0023.fq.gz' -i  5028 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101H_0024.fq.gz' -i  5029 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101H_0025.fq.gz' -i  5030 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101H_0026.fq.gz' -i  5031 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101H_0027.fq.gz' -i  5032 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101H_0029.fq.gz' -i  5033 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101H_0031.fq.gz' -i  5034 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101H_0032.fq.gz' -i  5035 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101H_0033.fq.gz' -i  5036 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101H_0034.fq.gz' -i  5037 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101H_0035.fq.gz' -i  5038 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101H_0038.fq.gz' -i  5039 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101H_0039.fq.gz' -i  5040 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101H_0040.fq.gz' -i  5041 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101H_0041.fq.gz' -i  5042 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101H_0047.fq.gz' -i  5043 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101H_0049.fq.gz' -i  5044 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101H_0050.fq.gz' -i  5045 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101H_0053.fq.gz' -i  5046 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101H_0055.fq.gz' -i  5047 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101H_0056.fq.gz' -i  5048 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101H_0058.fq.gz' -i  5049 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101H_0059.fq.gz' -i  5050 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101H_0062.fq.gz' -i  5051 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101H_0066.fq.gz' -i  5052 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101H_0067.fq.gz' -i  5053 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101H_0069.fq.gz' -i  5054 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101H_0070.fq.gz' -i  5055 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101H_0073.fq.gz' -i  5056 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101H_0075.fq.gz' -i  5057 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101H_0078.fq.gz' -i  5058 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101H_0101.fq.gz' -i  5059 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101H_0104.fq.gz' -i  5060 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0001.fq.gz' -i  5061 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0002.fq.gz' -i  5062 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0003.fq.gz' -i  5063 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0004.fq.gz' -i  5064 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0005.fq.gz' -i  5065 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0006.fq.gz' -i  5066 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0007.fq.gz' -i  5067 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0008.fq.gz' -i  5068 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0009.fq.gz' -i  5069 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0010.fq.gz' -i  5070 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0011.fq.gz' -i  5071 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0012.fq.gz' -i  5072 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0013.fq.gz' -i  5073 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0014.fq.gz' -i  5074 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0015.fq.gz' -i  5075 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0016.fq.gz' -i  5076 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0017.fq.gz' -i  5077 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0018.fq.gz' -i  5078 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0019.fq.gz' -i  5079 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0020.fq.gz' -i  5080 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0021.fq.gz' -i  5081 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0022.fq.gz' -i  5082 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0023.fq.gz' -i  5083 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0024.fq.gz' -i  5084 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0025.fq.gz' -i  5085 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0026.fq.gz' -i  5086 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0027.fq.gz' -i  5087 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0028.fq.gz' -i  5088 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0029.fq.gz' -i  5089 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0030.fq.gz' -i  5090 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0031.fq.gz' -i  5091 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0032.fq.gz' -i  5092 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0033.fq.gz' -i  5093 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0034.fq.gz' -i  5094 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0045.fq.gz' -i  5095 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X_0107.fq.gz' -i  5096 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101G_0001.fq.gz' -i  5097 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101G_0002.fq.gz' -i  5098 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101G_0003.fq.gz' -i  5099 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101G_0004.fq.gz' -i  5100 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101G_0005.fq.gz' -i  5101 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101G_0006.fq.gz' -i  5102 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101G_0007.fq.gz' -i  5103 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101G_0008.fq.gz' -i  5104 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101G_0009.fq.gz' -i  5105 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101G_0010.fq.gz' -i  5106 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101G_0011.fq.gz' -i  5107 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X101G_0012.fq.gz' -i  5108 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0035.fq.gz' -i  5109 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0036.fq.gz' -i  5110 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0037.fq.gz' -i  5111 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0038.fq.gz' -i  5112 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0039.fq.gz' -i  5113 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0040.fq.gz' -i  5114 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0041.fq.gz' -i  5115 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0042.fq.gz' -i  5116 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0043.fq.gz' -i  5117 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0044.fq.gz' -i  5118 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0046.fq.gz' -i  5119 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0047.fq.gz' -i  5120 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0048.fq.gz' -i  5121 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0049.fq.gz' -i  5122 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0050.fq.gz' -i  5123 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0051.fq.gz' -i  5124 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0052.fq.gz' -i  5125 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0053.fq.gz' -i  5126 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0054.fq.gz' -i  5127 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0055.fq.gz' -i  5128 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0056.fq.gz' -i  5129 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0057.fq.gz' -i  5130 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0059.fq.gz' -i  5131 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0060.fq.gz' -i  5132 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0061.fq.gz' -i  5133 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0062.fq.gz' -i  5134 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0063.fq.gz' -i  5135 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0064.fq.gz' -i  5136 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0065.fq.gz' -i  5137 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0066.fq.gz' -i  5138 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0067.fq.gz' -i  5139 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0068.fq.gz' -i  5140 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0069.fq.gz' -i  5141 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0070.fq.gz' -i  5142 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0071.fq.gz' -i  5143 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0072.fq.gz' -i  5144 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0073.fq.gz' -i  5145 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0074.fq.gz' -i  5146 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0075.fq.gz' -i  5147 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0076.fq.gz' -i  5148 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0077.fq.gz' -i  5149 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0078.fq.gz' -i  5150 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0079.fq.gz' -i  5151 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0080.fq.gz' -i  5152 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0081.fq.gz' -i  5153 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0082.fq.gz' -i  5154 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0083.fq.gz' -i  5155 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0084.fq.gz' -i  5156 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0085.fq.gz' -i  5157 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0086.fq.gz' -i  5158 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0087.fq.gz' -i  5159 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0088.fq.gz' -i  5160 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0089.fq.gz' -i  5161 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0090.fq.gz' -i  5162 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0091.fq.gz' -i  5163 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0092.fq.gz' -i  5164 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0093.fq.gz' -i  5165 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0094.fq.gz' -i  5166 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0095.fq.gz' -i  5167 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0096.fq.gz' -i  5168 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0097.fq.gz' -i  5169 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0098.fq.gz' -i  5170 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0099.fq.gz' -i  5171 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0100.fq.gz' -i  5172 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0101.fq.gz' -i  5173 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0102.fq.gz' -i  5174 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0103.fq.gz' -i  5175 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0104.fq.gz' -i  5176 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0105.fq.gz' -i  5177 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0106.fq.gz' -i  5178 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0107.fq.gz' -i  5179 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0109.fq.gz' -i  5180 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0110.fq.gz' -i  5181 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0111.fq.gz' -i  5182 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0113.fq.gz' -i  5183 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0114.fq.gz' -i  5184 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0115.fq.gz' -i  5185 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0116.fq.gz' -i  5186 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0117.fq.gz' -i  5187 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0122.fq.gz' -i  5188 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0123.fq.gz' -i  5189 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0124.fq.gz' -i  5190 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d 
! ustacks -f '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X107H_0126.fq.gz' -i  5191 -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -m 2 -M 2 -t gzfastq -p 7 -d
# Out:
# ustacks parameters selected:
#   Sample ID: 5000
#   Min depth of coverage to create a stack: 2
#   Max distance allowed between stacks: 2
#   Max distance allowed to align secondary reads: 4
#   Max number of stacks allowed per de novo locus: 3
#   Deleveraging algorithm: enabled
#   Removal algorithm: enabled
#   Model type: SNP
#   Alpha significance level for model: 0.05
#   Gapped alignments: disabled
# Parsing /media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014Stacks/PBIRD14X_0101.fq.gz
# Loading RAD-Tags...1M...2M...3M...done
# Loaded 3059977 RAD-Tags.
#   Inserted 353231 elements into the RAD-Tags hash map.
#   0 reads contained uncalled nucleotides that were modified.
# 110646 initial stacks were populated; 242585 stacks were set aside as secondary reads.
# Initial coverage mean: 25.4631; Std Dev: 74.6973; Max: 11914
# Deleveraging trigger: 100; Removal trigger: 175
# Calculating distance for removing repetitive stacks.
# ...

# %% [markdown]
# ## I'd already added variation from populations running cstacks before (catalog 3 -> catalog 4). Since we've added 2.8M reads sequence to one even-year dam I'm going to add it to the catalog again (catalog 4 -> 5) just to be safe.

# %%
! cstacks -p 7 -b 5 -n 2 -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X_0107' -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' --catalog '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/batch_4'
# Out:
# cstacks parameters selected:
#   Database/Batch ID: 5
#   Loci matched based on sequence identity.
#   Number of mismatches allowed between stacks: 2
#   Gapped alignments: disabled
# Constructing catalog from 1 samples.
#
# Initializing existing catalog...
#   Parsing /media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/batch_4.catalog.tags.tsv
#   Parsing /media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/batch_4.catalog.snps.tsv
#   Parsing /media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/batch_4.catalog.alleles.tsv
#
# Processing sample /media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X_0107 [1 of 1]
#   Parsing /media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X_0107.tags.tsv.gz
#   Parsing /media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X_0107.snps.tsv.gz
#   Parsing /media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X_0107.alleles.tsv.gz
# Searching for sequence matches...
# ...

# %% [markdown]
# ## sstacks to match sets of stacks to the catalog

# %%
! sstacks -b 5 -p 7 -c '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/batch_5' -o '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X_0101' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X_0107' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101G_0001' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101G_0002' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101G_0003' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101G_0004' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101G_0005' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101G_0006' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101G_0007' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101G_0008' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101G_0009' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101G_0010' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101G_0011' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101G_0012' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101G_0013' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101G_0014' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101G_0015' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101G_0016' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101G_0017' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101G_0018' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101G_0019' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101G_0020' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101G_0021' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101G_0022' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101G_0023' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101H_0002' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101H_0003' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101H_0005' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101H_0007' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101H_0009' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101H_0010' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101H_0011' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101H_0012' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101H_0013' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101H_0014' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101H_0015' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101H_0016' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101H_0017' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101H_0018' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101H_0019' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101H_0020' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101H_0023' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101H_0024' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101H_0025' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101H_0026' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101H_0027' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101H_0029' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101H_0031' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101H_0032' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101H_0033' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101H_0034' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101H_0035' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101H_0038' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101H_0039' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101H_0040' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101H_0041' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101H_0047' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101H_0049' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101H_0050' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101H_0053' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101H_0055' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101H_0056' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101H_0058' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101H_0059' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101H_0062' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101H_0066' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101H_0067' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101H_0069' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101H_0070' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101H_0073' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101H_0075' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101H_0078' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101H_0101' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101H_0104' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0001' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0002' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0003' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0004' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0005' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0006' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0007' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0008' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0009' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0010' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0011' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0012' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0013' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0014' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0015' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0016' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0017' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0018' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0019' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0020' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0021' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0022' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0023' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0024' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0025' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0026' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0027' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0028' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0029' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0030' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0031' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0032' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0033' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0034' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0035' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0036' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0037' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0038' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0039' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0040' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0041' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0042' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0043' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0044' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0045' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0046' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0047' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0048' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0049' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0050' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0051' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0052' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0053' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0054' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0055' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0056' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0057' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0059' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0060' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0061' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0062' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0063' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0064' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0065' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0066' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0067' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0068' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0069' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0070' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0071' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0072' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0073' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0074' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0075' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0076' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0077' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0078' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0079' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0080' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0081' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0082' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0083' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0084' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0085' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0086' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0087' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0088' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0089' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0090' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0091' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0092' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0093' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0094' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0095' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0096' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0097' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0098' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0099' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0100' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0101' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0102' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0103' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0104' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0105' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0106' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0107' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0109' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0110' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0111' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0113' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0114' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0115' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0116' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0117' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0122' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0123' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0124' -s '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X107H_0126'
# Out:
# Searching for matches by sequence identity...
#   Parsing /media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/batch_5.catalog.tags.tsv
#   Parsing /media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/batch_5.catalog.snps.tsv
#   Parsing /media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/batch_5.catalog.alleles.tsv
#
# Processing sample '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X_0101' [1 of 192]
#   Parsing /media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X_0101.tags.tsv.gz
#   Parsing /media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X_0101.snps.tsv.gz
#   Parsing /media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X_0101.alleles.tsv.gz
# Searching for sequence matches...
# 89950 stacks compared against the catalog containing 860147 loci.
#   88653 matching loci, 395 contained no verified haplotypes.
#   221 loci matched more than one catalog locus and were excluded.
# ...

# %%
## Running populations without filtering to do all in plink and Waples pipeline
! populations -P '/media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks' -M '/media/tyler/My Book/Stacks/Pink/Haploids2014/Bird2014PopulationsMap.txt' -b 5 -O '/media/tyler/My Book/Stacks/Pink/Haploids2014/Populations' -t 7 -s --genepop --plink --verbose
# Out:
# populations parameters selected:
#   Fst kernel smoothing: off
#   Bootstrap resampling: off
#   Percent samples limit per population: 0
#   Locus Population limit: 1
#   Minimum stack depth: 0
#   Log liklihood filtering: off; threshold: 0
#   Minor allele frequency cutoff: 0
#   Maximum observed heterozygosity cutoff: 1
#   Applying Fst correction: none.
#
# Parsing population map...
# The population map contained 192 samples, 3 population(s), 1 group(s).
# Reading the catalog...
#   Parsing /media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/batch_5.catalog.tags.tsv
#   Parsing /media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/batch_5.catalog.snps.tsv
#   Parsing /media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/batch_5.catalog.alleles.tsv
# Reading matches to the catalog...
#   Parsing /media/tyler/My Book/Stacks/Pink/Haploids2014/MapStacks/PBIRD14X101H_0002.matches.tsv.gz
# ...

# %% [markdown]
# ## Remove consensus and tally missing data

# %%
# !perl '/media/tyler/My Book/Stacks/Pink/Haploids2014/Populations/removeConsensus.pl' '/media/tyler/My Book/Stacks/Pink/Haploids2014/Populations/batch_5.haplotypes.tsv' > '/media/tyler/My Book/Stacks/Pink/Haploids2014/Populations/Bird2014HaplotypesNoConsensus.tsv'

# %%
# !perl '/media/tyler/My Book/Stacks/Pink/Haploids2014/Populations/countHetsMissing.pl' '/media/tyler/My Book/Stacks/Pink/Haploids2014/Populations/Bird2014HaplotypesNoConsensus.tsv' > '/media/tyler/My Book/Stacks/Pink/Haploids2014/Populations/Bird2014HetsMissingCountsInds.txt'

# %%
# !perl '/media/tyler/My Book/Stacks/Pink/Haploids2014/Populations/countHetsMissingLoci.pl' '/media/tyler/My Book/Stacks/Pink/Haploids2014/Populations/Bird2014HaplotypesNoConsensus.tsv' > '/media/tyler/My Book/Stacks/Pink/Haploids2014/Populations/Bird2014HetsMissingCountsLoci.txt'

# %% [markdown]
# It looks like sequencing rounds have been combined correctly based upon the percent of loci that are heterozygous.
# Missing data looks a little high, a 40% missing data cut-off will likely remove poor quality individuals.  The rate for offspring from 101H might be lower.
#
# I'll filter individuals first and then loci prior to Waples pipeline.

# %% [markdown]
# ## Remove individuals missing 40%+ loci and then reevaluate missingness of loci to filter loci
# ### 40% criterion selected after observing distributions

# %%
# !perl '/media/tyler/My Book/Stacks/Pink/Haploids2014/Populations/filterHaplotypeIndividuals.pl' '/media/tyler/My Book/Stacks/Pink/Haploids2014/Populations/Bird201440PercentMissingWhitelistInds.txt' '/media/tyler/My Book/Stacks/Pink/Haploids2014/Populations/Bird2014HaplotypesNoConsensus.tsv' > '/media/tyler/My Book/Stacks/Pink/Haploids2014/Populations/Bird2014HaplotypesNoConsensusFilteredInds.tsv'

# %%
# !perl '/media/tyler/My Book/Stacks/Pink/Haploids2014/Populations/countHetsMissingLoci.pl' '/media/tyler/My Book/Stacks/Pink/Haploids2014/Populations/Bird2014HaplotypesNoConsensusFilteredInds.tsv' > '/media/tyler/My Book/Stacks/Pink/Haploids2014/Populations/Bird2014HetsMissingCountsLociPostFilteringInds.txt'

# %% [markdown]
# ## Filtering loci by family based upon 80% rule (only including loci genotyped in 80%+ individuals within a family (101H and 107H)
# ### First subsetting individuals from families

# %%
# !perl '/media/tyler/My Book/Stacks/Pink/Haploids2014/Populations/filterHaplotypeIndividuals.pl' '/media/tyler/My Book/Stacks/Pink/Haploids2014/Populations/Family101HWhitelistInds.txt' '/media/tyler/My Book/Stacks/Pink/Haploids2014/Populations/Bird2014HaplotypesNoConsensusFilteredInds.tsv' > '/media/tyler/My Book/Stacks/Pink/Haploids2014/Populations/Family101HaplotypesNoConsensusFilteredInds.tsv'

# %%
# !perl '/media/tyler/My Book/Stacks/Pink/Haploids2014/Populations/filterHaplotypeIndividuals.pl' '/media/tyler/My Book/Stacks/Pink/Haploids2014/Populations/Family107HWhitelistInds.txt' '/media/tyler/My Book/Stacks/Pink/Haploids2014/Populations/Bird2014HaplotypesNoConsensusFilteredInds.tsv' > '/media/tyler/My Book/Stacks/Pink/Haploids2014/Populations/Family107HaplotypesNoConsensusFilteredInds.tsv'

# %%
# !perl '/media/tyler/My Book/Stacks/Pink/Haploids2014/Populations/filterHaplotypeLoci.pl' '/media/tyler/My Book/Stacks/Pink/Haploids2014/Populations/Family101HLoci80GenoWhitelist.txt' '/media/tyler/My Book/Stacks/Pink/Haploids2014/Populations/Family101HaplotypesNoConsensusFilteredInds.tsv' > '/media/tyler/My Book/Stacks/Pink/Haploids2014/Populations/Family101HaplotypesNoConsensusFilteredIndsLoci.tsv'

# %%
# !perl '/media/tyler/My Book/Stacks/Pink/Haploids2014/Populations/filterHaplotypeLoci.pl' '/media/tyler/My Book/Stacks/Pink/Haploids2014/Populations/Family107HLoci80GenoWhitelist.txt' '/media/tyler/My Book/Stacks/Pink/Haploids2014/Populations/Family107HaplotypesNoConsensusFilteredInds.tsv' > '/media/tyler/My Book/Stacks/Pink/Haploids2014/Populations/Family107HaplotypesNoConsensusFilteredIndsLoci.tsv'

# %% [markdown]
# ### Also filtering loci for the combined, two-family dataset, including only loci genotyped in 80%+ of all individuals (not family-specific as above)

# %%
# !perl '/media/tyler/My Book/Stacks/Pink/Haploids2014/Populations/filterHaplotypeLoci.pl' '/media/tyler/My Book/Stacks/Pink/Haploids2014/Populations/BothFamiliesLoci80GenoWhitelist.txt' '/media/tyler/My Book/Stacks/Pink/Haploids2014/Populations/Bird2014HaplotypesNoConsensusFilteredInds.tsv' > '/media/tyler/My Book/Stacks/Pink/Haploids2014/Populations/BothFamiliesHaplotypesNoConsensusFilteredIndsLoci.tsv'

# %% [markdown]
# ## Prepare files for Ryan's pipeline
#
# Exclude gynogenetic diploids (done above), order parents first followed by offspring, add five columns between catalog number and number of offspring, and five between number of offspring and first parent:
# Catalog ID Annotation Chr BP Consensus Sequence Num Parents Num Progeny Num SNPs SNPs Num Alleles Alleles Deleveraged PBIRD14X_0107

# %%
import os
os.chdir("/media/tyler/My Book/Stacks/Pink/Haploids2014/Waples_PSV_pipeline_files/Stacks_mapping/Python")

import _pickle as pickle
import numpy

import Stacks_SQL_class
from models_to_test import models_to_test

#Added to attempt phase switching
import switch_allele_functions as switchAlleles

# %%
## Move family files into pipeline directory
! cp '/media/tyler/My Book/Stacks/Pink/Haploids2014/Populations/Family101HapFileFormattedForWaplesPipeline.csv' '/media/tyler/My Book/Stacks/Pink/Haploids2014/Waples_PSV_pipeline_files/Family101HapFileFormattedForWaplesPipeline.csv'
! cp '/media/tyler/My Book/Stacks/Pink/Haploids2014/Populations/Family107HapFileFormattedForWaplesPipeline.csv' '/media/tyler/My Book/Stacks/Pink/Haploids2014/Waples_PSV_pipeline_files/Family107HapFileFormattedForWaplesPipeline.csv'
! cp '/media/tyler/My Book/Stacks/Pink/Haploids2014/Populations/BothFamiliesHapFileFormattedForWaplesPipeline.csv' '/media/tyler/My Book/Stacks/Pink/Haploids2014/Waples_PSV_pipeline_files/BothFamiliesHapFileFormattedForWaplesPipeline.csv'

# %%
# Load data created with export_sql.pl 

Bird101Fam = Stacks_SQL_class.Stacks_SQL(
    path = "/media/tyler/My Book/Stacks/Pink/Haploids2014/Waples_PSV_pipeline_files/Family101HapFileFormattedForWaplesPipeline.csv", 
    name = 'Bird101',
    num_parents = 1, 
    num_offspring = 42, 
    parent_offspring = (42,)
    )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-9a96c27a613a> in <module>()
#       6     num_parents = 1,
#       7     num_offspring = 42,
# ----> 8     parent_offspring = (42,)
#       9     )
#
# /media/tyler/My Book/Stacks/Pink/Haploids2014/Waples_PSV_pipeline_files/Stacks_mapping/Python/Stacks_SQL_class.py in __init__(self, path, name, num_parents, num_offspring, parent_offspring)
#      84                                                 offspring_genotypes.append(offspring_genotype)
#      85                                             zipped_offspring_genotypes = zip(self.offspring_of_parent[parent_str], offspring_genotypes)
# ---> 86                                             cross_genotypes = CatID_Cross_Genotypes(current_catID, zipped_offspring_genotypes, zipped_parent_genotypes)
# ...

# %%
# !python2 -m pip install ipykernel
# Out:
# /usr/bin/python2: No module named install
